# %% [markdown]
# <a href="https://colab.research.google.com/github/linux-bear/main/blob/master/NewburyFloodData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import csv

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0431a75a-50ea-40df-92c7-d5c6033c9b72" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0431a75a-50ea-40df-92c7-d5c6033c9b72">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('./NewburyFloodDataFlowOnly.csv')
df
# Out:
#          ReadingDate  ReadingValue
# 0       8/8/17 10:30         1.023
# 1       8/8/17 10:45         1.640
# 2       8/8/17 11:00         1.027
# 3       8/8/17 11:15         1.640
# 4       8/8/17 11:30         1.004
# ...              ...           ...
# 68407  4/12/23 13:00        16.345
# 68408  4/12/23 13:30        16.220
# 68409  4/12/23 14:00        16.345
# 68410  4/12/23 14:30        16.343
# 68411  4/12/23 15:00        16.342
#
# [68412 rows x 2 columns]

# %%
df['ReadingDate'] = pd.to_datetime(df['ReadingDate'], format="%m/%d/%y %H:%M")

# %%
df
# Out:
#               ReadingDate  ReadingValue
# 0     2017-08-08 10:30:00         1.023
# 1     2017-08-08 10:45:00         1.640
# 2     2017-08-08 11:00:00         1.027
# 3     2017-08-08 11:15:00         1.640
# 4     2017-08-08 11:30:00         1.004
# ...                   ...           ...
# 68407 2023-04-12 13:00:00        16.345
# 68408 2023-04-12 13:30:00        16.220
# 68409 2023-04-12 14:00:00        16.345
# 68410 2023-04-12 14:30:00        16.343
# 68411 2023-04-12 15:00:00        16.342
#
# [68412 rows x 2 columns]
